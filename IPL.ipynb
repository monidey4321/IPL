# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/data (3).csv')
df
# Out:
#       id  season        city      date                  team1  \
# 0      1    2008   Bangalore  18-04-08  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-08    Chennai Super Kings
# 2      3    2008       Delhi  19-04-08       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-08         Mumbai Indians
# 4      5    2008     Kolkata  20-04-08        Deccan Chargers
# ..   ...     ...         ...       ...                    ...
# 572  573    2016      Raipur  22-05-16       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-16          Gujarat Lions
# 574  575    2016       Delhi  25-05-16    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-16          Gujarat Lions
# 576  577    2016   Bangalore  29-05-16    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head()
# Out:
#    id  season        city      date                  team1  \
# 0   1    2008   Bangalore  18-04-08  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-08    Chennai Super Kings
# 2   3    2008       Delhi  19-04-08       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-08         Mumbai Indians
# 4   5    2008     Kolkata  20-04-08        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.tail()
# Out:
#       id  season       city      date                team1  \
# 572  573    2016     Raipur  22-05-16     Delhi Daredevils
# 573  574    2016  Bangalore  24-05-16        Gujarat Lions
# 574  575    2016      Delhi  25-05-16  Sunrisers Hyderabad
# 575  576    2016      Delhi  27-05-16        Gujarat Lions
# 576  577    2016  Bangalore  29-05-16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df['win_by_runs']
# Out:
# 0      140
# 1       33
# 2        0
# 3        0
# 4        0
#       ...
# 572      0
# 573      0
# 574     22
# 575      0
# 576      8
# Name: win_by_runs, Length: 577, dtype: int64

# %%
df['win_by_runs'].mean()
# Out:
# 13.7157712305026

# %%
df['win_by_runs'].median()
# Out:
# 0.0

# %%
df['win_by_runs'].mode()[0]
# Out:
# 0

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.columns.value_counts()
# Out:
# id                 1
# season             1
# umpire2            1
# umpire1            1
# venue              1
# player_of_match    1
# win_by_wickets     1
# win_by_runs        1
# winner             1
# dl_applied         1
# result             1
# toss_decision      1
# toss_winner        1
# team2              1
# team1              1
# date               1
# city               1
# umpire3            1
# Name: count, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (577, 18)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
df[2:9]
# Out:
#    id  season       city      date                team1  \
# 2   3    2008      Delhi  19-04-08     Rajasthan Royals
# 3   4    2008     Mumbai  20-04-08       Mumbai Indians
# 4   5    2008    Kolkata  20-04-08      Deccan Chargers
# 5   6    2008     Jaipur  21-04-08      Kings XI Punjab
# 6   7    2008  Hyderabad  22-04-08      Deccan Chargers
# 7   8    2008    Chennai  23-04-08  Chennai Super Kings
# 8   9    2008  Hyderabad  24-04-08      Deccan Chargers
#
#                          team2       toss_winner toss_decision  result  \
# 2             Delhi Daredevils  Rajasthan Royals           bat  normal
# 3  Royal Challengers Bangalore    Mumbai Indians           bat  normal
# 4        Kolkata Knight Riders   Deccan Chargers           bat  normal
# 5             Rajasthan Royals   Kings XI Punjab           bat  normal
# 6             Delhi Daredevils   Deccan Chargers           bat  normal
# 7               Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
df[7:]
# Out:
#       id  season        city      date                        team1  \
# 7      8    2008     Chennai  23-04-08          Chennai Super Kings
# 8      9    2008   Hyderabad  24-04-08              Deccan Chargers
# 9     10    2008  Chandigarh  25-04-08              Kings XI Punjab
# 10    11    2008   Bangalore  26-04-08  Royal Challengers Bangalore
# 11    12    2008     Chennai  26-04-08        Kolkata Knight Riders
# ..   ...     ...         ...       ...                          ...
# 572  573    2016      Raipur  22-05-16             Delhi Daredevils
# 573  574    2016   Bangalore  24-05-16                Gujarat Lions
# 574  575    2016       Delhi  25-05-16          Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-16                Gujarat Lions
# 576  577    2016   Bangalore  29-05-16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df[:5]
# Out:
#    id  season        city      date                  team1  \
# 0   1    2008   Bangalore  18-04-08  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-08    Chennai Super Kings
# 2   3    2008       Delhi  19-04-08       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-08         Mumbai Indians
# 4   5    2008     Kolkata  20-04-08        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df[2:5]
# Out:
#    id  season     city      date             team1  \
# 2   3    2008    Delhi  19-04-08  Rajasthan Royals
# 3   4    2008   Mumbai  20-04-08    Mumbai Indians
# 4   5    2008  Kolkata  20-04-08   Deccan Chargers
#
#                          team2       toss_winner toss_decision  result  \
# 2             Delhi Daredevils  Rajasthan Royals           bat  normal
# 3  Royal Challengers Bangalore    Mumbai Indians           bat  normal
# 4        Kolkata Knight Riders   Deccan Chargers           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2           0             Delhi Daredevils            0               9
# 3           0  Royal Challengers Bangalore            0               5
# 4           0        Kolkata Knight Riders            0               5
#
#   player_of_match             venue    umpire1         umpire2  umpire3
# 2     MF Maharoof  Feroz Shah Kotla  Aleem Dar  GA Pratapkumar      NaN
# ...

# %%
df['win_by_runs'].max()
# Out:
# 144

# %%
df['win_by_runs'].min()
# Out:
# 0

# %%
df.sort_values(by='win_by_runs')
# Out:
#       id  season           city      date                        team1  \
# 194  195    2011         Mumbai  20-04-11                Pune Warriors
# 256  257    2012  Visakhapatnam  09-04-12              Deccan Chargers
# 455  456    2014         Mumbai  28-05-14               Mumbai Indians
# 457  458    2014      Bangalore  01-06-14              Kings XI Punjab
# 458  459    2015        Kolkata  08-04-15               Mumbai Indians
# ..   ...     ...            ...       ...                          ...
# 236  237    2011     Dharamsala  17-05-11              Kings XI Punjab
# 351  352    2013      Bangalore  23-04-13  Royal Challengers Bangalore
# 497  498    2015      Bangalore  06-05-15  Royal Challengers Bangalore
# 0      1    2008      Bangalore  18-04-08        Kolkata Knight Riders
# 560  561    2016      Bangalore  14-05-16  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
df.groupby('win_by_runs').count()
# Out:
#               id  season  city  date  team1  team2  toss_winner  \
# win_by_runs
# 0            316     316   312   316    316    316          316
# 1              7       7     7     7      7      7            7
# 2              7       7     7     7      7      7            7
# 3              3       3     3     3      3      3            3
# 4              7       7     6     7      7      7            7
# ...          ...     ...   ...   ...    ...    ...          ...
# 111            1       1     1     1      1      1            1
# 130            1       1     1     1      1      1            1
# 138            1       1     1     1      1      1            1
# 140            1       1     1     1      1      1            1
# 144            1       1     1     1      1      1            1
#
#              toss_decision  result  dl_applied  winner  win_by_wickets  \
# win_by_runs
# 0                      316     316         316     313             316
# ...

# %%
df['win_by_runs'].fillna(df['win_by_runs'].mean(),inplace=True)
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df['win_by_runs'].fillna(df['win_by_runs'].median(),inplace=True)
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
plt.plot(df['id'],color="blue",label='id')
plt.legend()
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue='win_by_runs')
plt.show()

# %%
sns.barplot(x='team1',y='win_by_runs',data=df)
plt.show()

# %%
sns.barplot(x='win_by_wickets',y='win_by_runs',data=df,hue='winner')
plt.show()

# %%
sns.boxplot(x='team2',y='win_by_runs',data=df)
plt.show()

# %%
sns.displot(df['win_by_runs'])
plt.show()

# %%
corr=df[['win_by_wickets','win_by_runs']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='player_of_match',y='win_by_runs',data=df)
plt.show()

# %%
sns.histplot(df['win_by_runs'])
plt.show()
