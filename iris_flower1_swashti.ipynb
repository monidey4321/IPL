# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/iris (2).csv')
df
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
df.tail()
# Out:
#      150    4  setosa  versicolor  virginica
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   150         150 non-null    float64
#  1   4           150 non-null    float64
#  2   setosa      150 non-null    float64
#  3   versicolor  150 non-null    float64
#  4   virginica   150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df[2:5]
# Out:
#    150    4  setosa  versicolor  virginica
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
df[2:]
# Out:
#      150    4  setosa  versicolor  virginica
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# 5    5.4  3.9     1.7         0.4          0
# 6    4.6  3.4     1.4         0.3          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [148 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['150', '4', 'setosa', 'versicolor', 'virginica'], dtype='object')

# %%
df['setosa'].max()
# Out:
# 6.9

# %%
df['setosa'].min()
# Out:
# 1.0

# %%
df.shape
# Out:
# (150, 5)

# %%
df.shape[0]
# Out:
# 150

# %%
df.describe()
# Out:
#               150           4      setosa  versicolor   virginica
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333    1.000000
# std      0.828066    0.435866    1.765298    0.762238    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df['setosa']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: setosa, Length: 150, dtype: float64

# %%
df['versicolor'].mean()
# Out:
# 1.1993333333333336

# %%
df['versicolor'].median()
# Out:
# 1.3

# %%
df['versicolor'].mode()[0]
# Out:
# 0.2

# %%
df.sort_values(by='versicolor')
# Out:
#      150    4  setosa  versicolor  virginica
# 32   5.2  4.1     1.5         0.1          0
# 13   4.3  3.0     1.1         0.1          0
# 37   4.9  3.6     1.4         0.1          0
# 9    4.9  3.1     1.5         0.1          0
# 12   4.8  3.0     1.4         0.1          0
# ..   ...  ...     ...         ...        ...
# 140  6.7  3.1     5.6         2.4          2
# 114  5.8  2.8     5.1         2.4          2
# 100  6.3  3.3     6.0         2.5          2
# 144  6.7  3.3     5.7         2.5          2
# 109  7.2  3.6     6.1         2.5          2
#
# [150 rows x 5 columns]

# %%
df.isnull()
# Out:
#        150      4  setosa  versicolor  virginica
# 0    False  False   False       False      False
# 1    False  False   False       False      False
# 2    False  False   False       False      False
# 3    False  False   False       False      False
# 4    False  False   False       False      False
# ..     ...    ...     ...         ...        ...
# 145  False  False   False       False      False
# 146  False  False   False       False      False
# 147  False  False   False       False      False
# 148  False  False   False       False      False
# 149  False  False   False       False      False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# 150           150
# 4             150
# setosa        150
# versicolor    150
# virginica     150
# dtype: int64

# %%
df.isnull().value_counts()
# Out:
# 150    4      setosa  versicolor  virginica
# False  False  False   False       False        150
# Name: count, dtype: int64

# %%
df.nunique()

# %%
df[df.virginica>145]
# Out:
# Empty DataFrame
# Columns: [150, 4, versicolor, virginica]
# Index: []

# %%
df=df.drop(['setosa'],axis=1)
df
# Out:
#      150    4  versicolor  virginica
# 0    5.1  3.5         0.2          0
# 1    4.9  3.0         0.2          0
# 2    4.7  3.2         0.2          0
# 3    4.6  3.1         0.2          0
# 4    5.0  3.6         0.2          0
# ..   ...  ...         ...        ...
# 145  6.7  3.0         2.3          2
# 146  6.3  2.5         1.9          2
# 147  6.5  3.0         2.0          2
# 148  6.2  3.4         2.3          2
# 149  5.9  3.0         1.8          2
#
# [150 rows x 4 columns]

# %%
df.groupby('virginica').count()
# Out:
#            150   4  versicolor
# virginica
# 0           50  50          50
# 1           50  50          50
# 2           50  50          50

# %%
sns.pairplot(df,hue='virginica')
plt.show()

# %%
sns.barplot(x='versicolor',y='virginica',data=df)
plt.show()

# %%
df=[3,4,5,7]
plt.plot(df)
plt.plot(df,'*')
plt.show()

# %%
versicolor=df['versicolor']
plt.plot(versicolor,color='green')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x='versicolor',y='virginica',data=df)
plt.show()

# %%
df['virginica'].fillna(df['virginica'].mean(),inplace=True)
df.isnull().sum()
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
df['virginica'].fillna(df['virginica'].median(),inplace=True)
df.isnull().sum()
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
sns.displot(x='virginica',data=df)
plt.show()

# %%
corr=df[['setosa','versicolor','virginica']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='setosa',y='versicolor',data=df)
plt.show()

# %%
sns.scatterplot(x='setosa',y='versicolor',data=df,hue='virginica')
plt.show()

# %%
df['virginica'].hist(bins=20)
# Out:
# <Axes: >

# %%
sns.histplot(df['virginica'])
plt.show()
